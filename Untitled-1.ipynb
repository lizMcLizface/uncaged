# %%
def toSemitones(interval):
    if interval == 'W':
        return 2
    elif interval == 'H':
        return 1
    elif interval == 'A':
        return 3
    elif interval == 'P':
        return 4

def getOffsetNote(note, interval):
    chromatic_scale = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
    # Handle flats by converting to equivalent sharp
    note = note.replace('bb', '#').replace('b', '#')
    try:
        idx = chromatic_scale.index(note)
    except ValueError:
        raise ValueError(f"Note {note} not found in chromatic scale")
    step = toSemitones(interval)
    next_idx = (idx + step) % len(chromatic_scale)
    return chromatic_scale[next_idx]

def getScale(rootNote, intervals):
    firstNote = rootNote
    scale = [firstNote]
    for interval in intervals:
        nextNote = getOffsetNote(scale[-1], interval)
        scale.append(nextNote)
    return scale

def semitonesToInterval(semitones):
    if semitones == 1:
        return 'H'
    elif semitones == 2:
        return 'W'
    elif semitones == 3:
        return 'A'
    elif semitones == 4:
        return 'P'
    else:
        raise ValueError("Invalid number of semitones")
def notesToIntervals(notes):
    chromatic_scale = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
    intervals = []
    for i in range(len(notes) - 1):
        note1 = notes[i]
        note2 = notes[i + 1]
        idx1 = chromatic_scale.index(note1)
        idx2 = chromatic_scale.index(note2)
        step = (idx2 - idx1) % len(chromatic_scale)
        intervals.append(semitonesToInterval(step))
    return intervals

# %%
def getRotations(intervals):
    print("Rotations:")
    for i in range(len(intervals)):
        rotation = intervals[i:] + intervals[:i]
        print(f"Rotation {i}: {rotation}")
        
getRotations(['W', 'W', 'A', 'W', 'A'])
# Out:
# Rotations:
# Rotation 0: ['W', 'W', 'A', 'W', 'A']
# Rotation 1: ['W', 'A', 'W', 'A', 'W']
# Rotation 2: ['A', 'W', 'A', 'W', 'W']
# Rotation 3: ['W', 'A', 'W', 'W', 'A']
# Rotation 4: ['A', 'W', 'W', 'A', 'W']

# %%
NeapolitanMajor = ['H', 'W', 'W', 'W', 'W', 'W', 'H']
# Rotation 0: ['H', 'W', 'W', 'W', 'W', 'W', 'H']
# Rotation 1: ['W', 'W', 'W', 'W', 'W', 'H', 'H']
# Rotation 2: ['W', 'W', 'W', 'W', 'H', 'H', 'W']
# Rotation 3: ['W', 'W', 'W', 'H', 'H', 'W', 'W']
# Rotation 4: ['W', 'W', 'H', 'H', 'W', 'W', 'W']
# Rotation 5: ['W', 'H', 'H', 'W', 'W', 'W', 'W']
# Rotation 6: ['H', 'H', 'W', 'W', 'W', 'W', 'W']

Scales = [ {
        'name': 'Neapolitan Major',
        'intervals': ['H', 'W', 'W', 'W', 'W', 'W', 'H'],
        'alternativeNames': ['Neapolitan Major']
    },{
        'name': 'Leading Whole Tone',
        'intervals': ['W', 'W', 'W', 'W', 'W', 'H', 'H'],
        'alternativeNames': ['Leading Whole Tone', 'Lydian Augmented ♯6']
    },{
        'name': 'Lydian Augmented Dominant',
        'intervals': ['W', 'W', 'W', 'W', 'H', 'H', 'W'],
        'alternativeNames': ['Lydian Augmented Dominant']
    },{
        'name': 'Lydian Dominant ♭6',
        'intervals': ['W', 'W', 'W', 'H', 'H', 'W', 'W'],
        'alternativeNames': ['Lydian Dominant ♭6', 'Melodic Major ♯4']
    },{
        'name': 'Major Locrian',
        'intervals': ['W', 'W', 'H', 'H', 'W', 'W', 'W'],
        'alternativeNames': ['']
    },{
        'name': 'Half-Diminished ♭4',
        'intervals': ['W', 'H', 'H', 'W', 'W', 'W', 'W'],
        'alternativeNames': ['Half-Diminished ♭4', 'Altered Dominant #2']
    },{
        'name': 'Altered Dominant 𝄫3',
        'intervals': ['H', 'H', 'W', 'W', 'W', 'W', 'W'],
        'alternativeNames': ['Altered Dominant 𝄫3']
    },
    
]


Scales = [
    {
        'name': 'Neapolitan Minor',
        'intervals': ['H', 'W', 'W', 'W', 'H', 'A', 'H'],
        'alternativeNames': ['Neapolitan Minor']
    },
    {
        'name': 'Lydian ♯6',
        'intervals': ['W', 'W', 'W', 'H', 'A', 'H', 'H'],
        'alternativeNames': ['Lydian ♯6']
    },
    {
        'name': 'Mixolydian Augmented',
        'intervals': ['W', 'W', 'H', 'A', 'H', 'H', 'W'],
        'alternativeNames': ['Mixolydian Augmented']
    },
    {
        'name': 'Romani Minor',
        'intervals': ['W', 'H', 'A', 'H', 'H', 'W', 'W'],
        'alternativeNames': ['Romani Minor', 'Aeolian ♯4', 'Natural Minor ♯4']
    },
    {
        'name': 'Locrian Dominant',
        'intervals': ['H', 'A', 'H', 'H', 'W', 'W', 'W'],
        'alternativeNames': ['Locrian Dominant']
    },
    {
        'name': 'Ionian ♯2',
        'intervals': ['A', 'H', 'H', 'W', 'W', 'W', 'H'],
        'alternativeNames': ['Ionian ♯2', 'Major ♯2']
    },
    {
        'name': 'Ultralocrian 𝄫3',
        'intervals': ['H', 'H', 'W', 'W', 'W', 'H', 'A'],
        'alternativeNames': ['Ultralocrian 𝄫3', 'Altered Diminished double flat3']
    }
    
]

# %%
IonianMajor = [1,2,3,4,5,6,7]

HeptatonicScales = {
    'Major': [
        {'name': 'Ionian', 'intervals': ['W', 'W', 'H', 'W', 'W', 'W', 'H'], 'alternativeNames': ['Ionian', 'Major']},
        {'name': 'Dorian', 'intervals': ['W', 'H', 'W', 'W', 'W', 'H', 'W'], 'alternativeNames': ['Dorian']},
        {'name': 'Phrygian', 'intervals': ['H', 'W', 'W', 'W', 'H', 'W', 'W'], 'alternativeNames': ['Phrygian']},
        {'name': 'Lydian', 'intervals': ['W', 'W', 'W', 'H', 'W', 'H', 'W'], 'alternativeNames': ['Lydian']},
        {'name': 'Mixolydian', 'intervals': ['W', 'W', 'H', 'W', 'W', 'H', 'W'], 'alternativeNames': ['Mixolydian']},
        {'name': 'Aeolian', 'intervals': ['W', 'H', 'W', 'W', 'H', 'W', 'W'], 'alternativeNames': ['Aeolian', 'Natural Minor']},
        {'name': 'Locrian', 'intervals': ['H', 'W', 'W', 'H', 'W', 'W', 'W'], 'alternativeNames': ['Locrian']}
    ],
    'Harmonic Minor':[{
        'name': 'Harmonic Minor',
        'intervals': ['W', 'H', 'W', 'W', 'H', 'A', 'H'],
        'alternativeNames': ['Harmonic Minor', 'Aeolian ♮7']
    }, {
        'name': 'Locrian ♮6',
        'intervals': ['H', 'W', 'W', 'H', 'A', 'H', 'W'],
        'alternativeNames': ['Locrian ♮6']
    }, {
        'name': 'Ionian ♯5',
        'intervals': ['W', 'W', 'H', 'A', 'H', 'W', 'H'],
        'alternativeNames': ['Ionian ♯5', 'Augmented Major']
    },{
        'name': 'Ukrainian Dorian',
        'intervals': ['W', 'H', 'A', 'H', 'W', 'H', 'W'],
        'alternativeNames': ['Ukrainian Dorian', 'Dorian #11', 'Dorian #4', 'Romanian Minor', 'Arabic Nikriz', 'Mi Sheberakh', 'altered Dorian']
    },{
        'name': 'Phrygian Dominant',
        'intervals': ['H', 'A', 'H', 'W', 'H', 'W', 'W'],
        'alternativeNames': ['Phrygian Dominant', 'Hijaz', 'Double Harmonic Major ♭7', 'Freygish']
    },{
        'name': 'Lydian #9',
        'intervals': ['A', 'H', 'W', 'H', 'W', 'W', 'H'],
        'alternativeNames': ['Lydian #9']
    },{
        'name': 'Super-Locrian scale 𝄫7',
        'intervals': ['H', 'W', 'H', 'W', 'W', 'H', 'A'],
        'alternativeNames': ['Super-Locrian scale 𝄫7', 'altered diminished', 'Ultralocian']
    }],
    'Harmonic Major': [
    {
        'name': 'Harmonic Major',
        'alternativeNames': ['Harmonic Major'],
        'intervals': ['W', 'W', 'H', 'W', 'H', 'A', 'H']
    },
    {
        'name': 'Locrian ♮2 ♮6',
        'alternativeNames': ['Locrian ♮2 ♮6', 'Dorian ♭5'],
        'intervals': ['W', 'H', 'W', 'H', 'A', 'H', 'W']
    },
    {
        'name': 'Altered Dominant ♮5',
        'alternativeNames': ['Altered Dominant ♮5', 'Phrygian ♭4'],
        'intervals': ['H', 'W', 'H', 'A', 'H', 'W', 'W']
    },
    {
        'name': 'Jazz Minor ♯4',
        'alternativeNames': ['Jazz Minor ♯4', 'Lydian ♭3'],
        'intervals': ['W', 'H', 'A', 'H', 'W', 'W', 'H']
    },
    {
        'name': 'Mixolydian ♭2',
        'alternativeNames': ['Mixolydian ♭2'],
        'intervals': ['H', 'A', 'H', 'W', 'W', 'H', 'W']
    },
    {
        'name': 'Lydian Augmented ♯2',
        'alternativeNames': ['Lydian Augmented ♯2'],
        'intervals': ['A', 'H', 'W', 'W', 'H', 'W', 'H']
    },
    {
        'name': "Locrian 𝄫7",
        'alternativeNames': ["Locrian 𝄫7"],
        'intervals': ['H', 'W', 'W', 'H', 'W', 'H', 'A']
    }
    ],
    'Melodic Minor': [{
        'name': 'Melodic Minor',
        'intervals': ['W', 'H', 'W', 'W', 'W', 'W', 'H'],
        'alternativeNames': ['Melodic Minor', 'Jazz Minor']
    }, {
        'name': 'Dorian ♭2',
        'intervals': ['H', 'W', 'W', 'W', 'W', 'H', 'W'],
        'alternativeNames': ['Dorian ♭2', 'Phrygian ♮6']
    }, {
        'name': 'Lydian Augmented',
        'intervals': ['W', 'W', 'W', 'W', 'H', 'W', 'H'],
        'alternativeNames': ['Lydian Augmented']
    },{
        'name': 'Acoustic scale',
        'intervals': ['W', 'W', 'W', 'H', 'W', 'H', 'W'],
        'alternativeNames': ['Acoustic scale', 'Lydian Dominant', 'Mixolydian ♯4', 'Overtone']
    },{
        'name': 'Aeolian dominant',
        'intervals': ['W', 'W', 'H', 'W', 'H', 'W', 'W'],
        'alternativeNames': ['Mixolydian ♭6', 'Aeolian dominant', 'Descending Melodic Minor', 'Hindu']
    }, {
        'name': 'Half Diminished',
        'intervals': ['W', 'H', 'W', 'H', 'W', 'W', 'W'],
        'alternativeNames': ['Aeolian ♭5', 'Half Diminished', 'Locrian ♮2']
    }, {
        'name': 'Altered Scale',
        'intervals': ['H', 'W', 'H', 'W', 'W', 'W', 'W'],
        'alternativeNames': ['Altered Scale', 'Super Locrian', 'Altered Dominant']
    }],
    'Double Harmonic Major':[
        {'name': 'Double Harmonic Major', 
        'intervals': ['H', 'A', 'H', 'W', 'H', 'A', 'H'],
        'alternativeNames': ['Double Harmonic Major', 'Byzantine', 'Gypsy Major', 'Arabic']
        },
        {
            'name': 'Lydian ♯2 ♯6',
            'intervals': ['A', 'H', 'W', 'H', 'A', 'H', 'H'],
            'alternativeNames': ['Lydian ♯2 ♯6']
        },
        {
            'name': 'Ultraphrygian',
            'intervals': ['H', 'W', 'H', 'A', 'H', 'H', 'A'],
            'alternativeNames': ['Ultraphrygian']
        },
        {
            'name': 'Hungarian',
            'intervals': ['W', 'H', 'A', 'H', 'H', 'A', 'H'],
            'alternativeNames': ['Hungarian', 'Gypsy Minor']
        },
        {
            'name': 'Oriental',
            'intervals': ['H', 'A', 'H', 'H', 'A', 'H', 'W'],
            'alternativeNames': ['Oriental']
        },
        {
            'name': 'Ionian ♯2 ♯5',
            'intervals': ['A', 'H', 'H', 'A', 'H', 'W', 'H'],
            'alternativeNames': ['Ionian ♯2 ♯5']
        },
        {
            'name': 'Locrian 𝄫3 𝄫7',
            'intervals': ['H', 'H', 'A', 'H', 'W', 'H', 'A'],
            'alternativeNames': ['Locrian 𝄫3 𝄫7']
        }
    ],
    'Neapolitan Major': [ {
        'name': 'Neapolitan Major',
        'intervals': ['H', 'W', 'W', 'W', 'W', 'W', 'H'],
        'alternativeNames': ['Neapolitan Major']
    },{
        'name': 'Leading Whole Tone',
        'intervals': ['W', 'W', 'W', 'W', 'W', 'H', 'H'],
        'alternativeNames': ['Leading Whole Tone', 'Lydian Augmented ♯6']
    },{
        'name': 'Lydian Augmented Dominant',
        'intervals': ['W', 'W', 'W', 'W', 'H', 'H', 'W'],
        'alternativeNames': ['Lydian Augmented Dominant']
    },{
        'name': 'Lydian Dominant ♭6',
        'intervals': ['W', 'W', 'W', 'H', 'H', 'W', 'W'],
        'alternativeNames': ['Lydian Dominant ♭6', 'Melodic Major ♯4']
    },{
        'name': 'Major Locrian',
        'intervals': ['W', 'W', 'H', 'H', 'W', 'W', 'W'],
        'alternativeNames': ['']
    },{
        'name': 'Half-Diminished ♭4',
        'intervals': ['W', 'H', 'H', 'W', 'W', 'W', 'W'],
        'alternativeNames': ['Half-Diminished ♭4', 'Altered Dominant #2']
    },{
        'name': 'Altered Dominant 𝄫3',
        'intervals': ['H', 'H', 'W', 'W', 'W', 'W', 'W'],
        'alternativeNames': ['Altered Dominant 𝄫3']
    },
    
],
    'Neapolitan Minor': [
    {
        'name': 'Neapolitan Minor',
        'intervals': ['H', 'W', 'W', 'W', 'H', 'A', 'H'],
        'alternativeNames': ['Neapolitan Minor']
    },
    {
        'name': 'Lydian ♯6',
        'intervals': ['W', 'W', 'W', 'H', 'A', 'H', 'H'],
        'alternativeNames': ['Lydian ♯6']
    },
    {
        'name': 'Mixolydian Augmented',
        'intervals': ['W', 'W', 'H', 'A', 'H', 'H', 'W'],
        'alternativeNames': ['Mixolydian Augmented']
    },
    {
        'name': 'Romani Minor',
        'intervals': ['W', 'H', 'A', 'H', 'H', 'W', 'W'],
        'alternativeNames': ['Romani Minor', 'Aeolian ♯4', 'Natural Minor ♯4']
    },
    {
        'name': 'Locrian Dominant',
        'intervals': ['H', 'A', 'H', 'H', 'W', 'W', 'W'],
        'alternativeNames': ['Locrian Dominant']
    },
    {
        'name': 'Ionian ♯2',
        'intervals': ['A', 'H', 'H', 'W', 'W', 'W', 'H'],
        'alternativeNames': ['Ionian ♯2', 'Major ♯2']
    },
    {
        'name': 'Ultralocrian 𝄫3',
        'intervals': ['H', 'H', 'W', 'W', 'W', 'H', 'A'],
        'alternativeNames': ['Ultralocrian 𝄫3', 'Altered Diminished double flat3']
    }
    
],
}

HexatonicScales = [
    {
        'name': 'Major Hexatonic',
        'alternativeNames': ['Major Hexatonic'],
        'intervals': ['W', 'W', 'H', 'W', 'W', 'A']
    },
    {
        'name': 'Minor Hexatonic',
        'alternativeNames': ['Minor Hexatonic'],
        'intervals':['W', 'H', 'W', 'W', 'A', 'W']
    },
    {
        'name': "Ritsu Onkai",
        'alternativeNames': ['Ritsu Onkai'],
        'intervals': ['H', 'W', 'W', 'A', 'W', 'W']
    },
    {
        'name': 'Raga Kumud',
        'alternativeNames': ['Raga Kumud'],
        'intervals': ['W', 'W', 'A', 'W', 'H', 'W']
    },
    {
        'name': 'Mixolydian hexatonic',
        'alternativeNames': ['Mixolydian hexatonic'],
        'intervals': ['W', 'A', 'W', 'W', 'H', 'W']
    },
    {
        'name': 'Phyrgian hexatonic',
        'alternativeNames': ['Phyrgian hexatonic'],
        'intervals': ['A', 'W', 'W', 'H', 'W', 'W']
    },
    # {
    #     'name': 'Augmented Scale',
    #     'alternativeNames': ['Augmented Scale'],
    #     'intervals': ['A', 'H', 'A', 'H', 'A', 'H']
    # },
    # {
    #     'name': 'Prometheus Scale',
    #     'alternativeNames': ['Prometheus Scale'],
    #     'intervals': ['W', 'W', 'W', 'A', 'H', 'W']
    # },
    {
        'name': 'Blues',
        'alternativeNames': ['Blues'],
        'intervals': ['A', 'W', 'H', 'H', 'A', 'W']
    }
    
]

PentatonicScales = [
    {
        'name': 'Major Pentatonic',
        'alternativeNames': ['Major Pentatonic', 'gōng', 'Bhoopali', 'Mohanam', 'Mullaittīmpāṇi'],
        'intervals': ['W', 'W', 'A', 'W', 'A']
    },
    {
        'name': 'Egyptian',
        'alternativeNames': ['Egyptian', 'Suspended', 'shāng', 'Megh', 'Madhyamavati', 'Centurutti'],
        'intervals': ['W', 'A', 'W', 'A', 'W']
    },
    {
        'name': 'Blues Minor',
        'alternativeNames': ['Blues Minor', 'Man Gong', 'jué', 'Malkauns', 'Hindolam', 'Intaḷam'],
        'intervals': ['A', 'W', 'A', 'W', 'W']
    },
    {
        'name': 'Blues Major',
        'alternativeNames': ['Blues Major', 'ritsusen', 'yo', 'zhǐ', 'Durga', 'Shuddha Saveri', 'Koṉṟai'],
        'intervals': ['W', 'A', 'W', 'W', 'A']
    },
    {
        'name': 'Minor Pentatonic',
        'alternativeNames': ['Minor Pentatonic', 'yǔ', 'Dhani', 'Shuddha Dhanyāsī', 'āmpal'],
        'intervals': ['A', 'W', 'W', 'A', 'W']
    },
    {
        'name': 'Japanese',
        'alternativeNames': ['Japanese', 'Insen', 'Ryukyu'],
        'intervals:': ['W', 'H', 'P', 'H', 'P']
    }
]

# %%
scales = [
    {
        'notes': 7,
        'name': 'Heptatonic',
        'scales': HeptatonicScales
    },
    {
        'notes': 6,
        'name': 'Hexatonic',
        'scales': HexatonicScales
    },
    {
        'notes': 5,
        'name': 'Pentatonic',
        'scales': PentatonicScales
    }
]

# %%
import re


chordName = 'C#m#7'

def intervalToSemitones(interval):
    if interval == 'P1' or interval == 'd2':
        return 0
    elif interval == 'm2' or interval == 'A1':
        return 1
    elif interval == 'M2' or interval == 'd3':
        return 2    
    elif interval == 'm3' or interval == 'A2':
        return 3
    elif interval == 'M3' or interval == 'd4':
        return 4
    elif interval == 'P4' or interval == 'A3':
        return 5
    elif interval == 'd5' or interval == 'A4':
        return 6
    elif interval == 'P5' or interval == 'd6':
        return 7
    elif interval == 'm6' or interval == 'A5':
        return 8
    elif interval == 'M6' or interval == 'd7':
        return 9
    elif interval == 'm7' or interval == 'A6':
        return 10
    elif interval == 'M7' or interval == 'd8':
        return 11
    elif interval == 'P8' or interval == 'A7' or interval == 'd9':
        return 12
    elif interval == 'm9' or interval == 'A8':
        return 13   
    elif interval == 'M9' or interval == 'd10':
        return 14
    elif interval == 'm10' or interval == 'A9':
        return 15
    elif interval == 'M10' or interval == 'd11':
        return 16
    elif interval == 'P11' or interval == 'A10':
        return 17
    elif interval == 'd12' or interval == 'A11':
        return 18
    elif interval == 'P12' or interval == 'd13':
        return 19
    elif interval == 'm13' or interval == 'A12':
        return 20
    elif interval == 'M13' or interval == 'd14':
        return 21
    elif interval == 'm14' or interval == 'A13':
        return 22
    elif interval == 'M14' or interval == 'd15':
        return 23
    elif interval == 'P15' or interval == 'A14':
        return 24
    else:
        raise ValueError(f"Unknown interval: {interval}")
    
    

def resolveChord(chordName):
    chordName = chordName.replace(' ', '').replace(' ', '').replace('Major','maj').replace('Minor', 'min')

    flatNotes = []
    if 'b3' in chordName or 'b5' in chordName or 'b7' in chordName:
        if 'b3' in chordName:
            flatNotes.append(3)
            chordName = chordName.replace('b3', '')
        if 'b5' in chordName:
            flatNotes.append(5)
            chordName = chordName.replace('b5', '')
        if 'b7' in chordName:
            flatNotes.append(7)
            chordName = chordName.replace('b7', '')
    # sharpNotes = []
    # if '#3' in chordName or '#5' in chordName or '#7' in chordName:
    #     if '#3' in chordName:
    #         sharpNotes.append(3)
    #         chordName = chordName.replace('#3', '')
    #     if '#5' in chordName:
    #         sharpNotes.append(5)
    #         chordName = chordName.replace('#5', '')
    #     if '#7' in chordName:
    #         sharpNotes.append(7)
    #         chordName = chordName.replace('#7', '')
            
    noteRegex = r'([A-G](?:b|#|♮|♭|♯|𝄫|𝄪|))(.*)'
    noteRegex2 = r'(.*)/([A-G](?:b|#|♮|♭|♯|𝄫|𝄪|))'

    result = re.match(noteRegex, chordName)
    # print(result.group(1))  # This will print the matched note, e.g., 'C#'
    rootNote = result.group(1)
    if not rootNote:
        raise ValueError("Invalid chord name: No root note found")
    
    # print(f"Root Note: {rootNote}")
    subString = result.group(2)
    result = re.match(noteRegex2, subString)
    if result:
        chordType = result.group(1)
        bassNote = result.group(2)
        # print(f"Chord Type: {chordType}, Bass Note: {bassNote}")
    else:
        chordType = subString
        bassNote = None
        # print(f"Chord Type: {chordType}")
    
    
    suspended = None
    if 'sus' in chordType:
        if 'sus2' in chordType:
            suspended = 'sus2'
            chordType = chordType.replace('sus2', '')
        elif 'sus4' in chordType:
            suspended = 'sus4'
            chordType = chordType.replace('sus4', '')
        elif 'sus' in chordType:
            suspended = 'sus4'
            chordType = chordType.replace('sus', '')
    # print(f"Suspended: {suspended}, Chord Type: {chordType}")
    
    addedTone = None
    if 'add' in chordType:
        addRegex = r'add(\d+)'
        addMatch = re.search(addRegex, chordType)
        if addMatch:
            addedTone = addMatch.group(1)
            chordType = chordType.replace(f'add{addedTone}', '')
            # print(f"Added Tone: {addedTone}")
    # print(f"Chord Type after processing: {chordType}")
    noTone = None
    if 'no' in chordType:
        noRegex = r'no(\d+)'
        noMatch = re.search(noRegex, chordType)
        if noMatch:
            noTone = noMatch.group(1)
            chordType = chordType.replace(f'no{noTone}', '')
            # print(f"No Tone: {noTone}")
    
    chord = None
    chordType.replace('♯', '#').replace('♭', 'b').replace('𝄫', 'bb').replace('𝄪', '##')
    chordType= chordType.replace('♮', '').replace('°', 'o').replace('Δ', 'D')
    
    # print(f"Final Chord Type: {chordType}")
    
    if chordType in ['', 'maj', 'M', 'Δ', 'D']:
        chord = 'Major Triad'
    elif chordType in ['min', 'm', '−']:
        chord = 'Minor Triad'
    elif chordType in ['dim', '°', 'o', 'm♭5', 'mo5', 'm°5']:
        chord = 'Diminished Triad'
    elif chordType in ['aug', '+', 'M♯5', 'M+5']:
        chord = 'Augmented Triad'
    elif chordType in ['5']:
        chord = 'Power Chord'
    elif chordType in ['7', 'Mm7', 'maj♭7', 'majm7', 'majb7']:
        chord = 'Dominant Seventh'
    elif chordType in ['m7', 'min7', '−7', '−7']:
        chord = 'Minor Seventh'
    elif chordType in ['mM7', 'm#7', '-M7', '-Δ7', 'minmaj7', 'm♯7', '-D7']:
        chord = 'Minor Major Seventh'
    elif chordType in ['M7', 'Ma7', 'maj7', 'Δ7', 'D7']:
        chord = 'Major Seventh'
    elif chordType in ['+M7', '+D', 'augmaj7', 'M7#5', 'M7+5', 'D#5, D+5']:
        chord = 'Augmented Major Seventh'
    elif chordType in ['+7', 'aug7', '7#5', '7+5']:
        chord = 'Augmented Seventh'
    elif chordType in ['ø', 'ø7', 'min7dim5', 'm7b5', 'm7o5','-7b5', '-7o5']:
        chord = 'Half Diminished Seventh'
    elif chordType in ['o7', 'dim7']:
        chord = 'Diminished Seventh'
    elif chordType in ['7b5', '7dim5']:
        chord = 'Diminished Seventh Flat Five'
    elif chordType in [ 'M9', 'D9', 'maj9']:
        chord = 'Major Ninth'
    elif chordType in ['m9', 'min9', '−9']:
        chord = 'Minor Ninth'
    elif chordType in ['9']:
        chord = 'Dominant Ninth'
    elif chordType in ['7b9']:
        chord = 'Dominant minor Ninth'
    elif chordType in ['mM9', '-M9', 'minmaj9']:
        chord = 'Minor Major Ninth'
    elif chordType in ['+M9', 'augmaj9']:
        chord = 'Augmented Major Ninth'
    elif chordType in ['+9', '9#5', 'aug9']:
        chord = 'Augmented dominant ninth'
    elif chordType in ['ø9']:
        chord = 'Half Diminished Ninth'
    elif chordType in ['øb9']:
        chord = 'Half Diminished minor Ninth'
    elif chordType in ['o9', 'dim9']:
        chord = 'Diminished Ninth'
    elif chordType in [ 'ob9', 'dimb9']:
        chord = 'Diminished minor Ninth'
    elif chordType  in ['11']:
        chord = 'Eleventh'
    elif chordType in ['m11', 'min11', '−11']:
        chord = 'Minor Eleventh'
    elif chordType in ['M11', 'maj11', 'D11']:
        chord = 'Major Eleventh'
    elif chordType in ['mM11', '-M11', 'minmaj11']:
        chord = 'Minor Major Eleventh'
    elif chordType in ['+M11', 'augmaj11']:
        chord = 'Augmented Major Eleventh'
    elif chordType in ['+11', '11#5', 'aug11']:
        chord = 'Augmented Eleventh'
    elif chordType in ['ø11']:
        chord = 'Half Diminished Eleventh'
    elif chordType in ['o11', 'dim11']:
        chord = 'Diminished Eleventh'
    elif chordType in ['M13', 'maj13', 'D13']:
        chord = 'Major Thirteenth'
    elif chordType in ['m13', 'min13', '−13']:
        chord = 'Minor Thirteenth'
    elif chordType in ['13']:
        chord = 'Dominant Thirteenth'
    elif chordType in ['mM13', '-M13', 'minmaj13']:
        chord = 'Minor Major Thirteenth'
    elif chordType in ['+M13', 'augmaj13']:
        chord = 'Augmented Major Thirteenth'
    elif chordType in ['+13', '13#5', 'aug13']:
        chord = 'Augmented Thirteenth'
    elif chordType in ['ø13']:
        chord = 'Half Diminished Thirteenth'
    elif chordType in ['m6', 'min6', '−6']:
        chord = 'Minor Sixth'
    elif chordType in ['M6', 'maj6', '6']:
        chord = 'Major Sixth'
    else:
        raise ValueError(f"Unknown chord type: {chordType}")
    
    return {
        'rootNote': rootNote,
        'chordType': chord,
        'suspended': suspended,
        'addedTone': addedTone,
        'bassNote': bassNote,
        'noTone': noTone,
        'flatNotes': flatNotes,
        'sharpNotes': [],
    }
        
            
chordName = 'C#m#7'
chordName = 'C#m#7sus4add7/B#'
print(resolveChord(chordName))
# Out:
# {'rootNote': 'C#', 'chordType': 'Minor Major Seventh', 'suspended': 'sus4', 'addedTone': '7', 'bassNote': 'B#', 'noTone': None, 'flatNotes': [], 'sharpNotes': []}

# %%
def chordToIntervals(chordType):
    chordName = chordType.strip().lower()
    if chordName == 'major triad':
        return ['P1', 'M3', 'P5']
    elif chordName == 'minor triad':
        return ['P1', 'm3', 'P5']
    elif chordName == 'diminished triad':
        return ['P1', 'm3', 'd5']
    elif chordName == 'augmented triad':
        return ['P1', 'M3', 'A5']
    elif chordName == 'power chord':
        return ['P1', 'P5']
    elif chordName == 'dominant seventh':
        return ['P1', 'M3', 'P5', 'm7']
    elif chordName == 'minor seventh':
        return ['P1', 'm3', 'P5', 'm7']
    elif chordName == 'minor major seventh':
        return ['P1', 'm3', 'P5', 'M7']
    elif chordName == 'major seventh':
        return ['P1', 'M3', 'P5', 'M7']
    elif chordName == 'augmented major seventh':
        return ['P1', 'M3', 'A5', 'M7']
    elif chordName == 'augmented seventh':
        return ['P1', 'M3', 'A5', 'm7']
    elif chordName == 'half diminished seventh':
        return ['P1', 'm3', 'd5', 'm7']
    elif chordName == 'diminished seventh':
        return ['P1', 'm3', 'd5', 'd7']
    elif chordName == 'diminished seventh flat five':
        return ['P1', 'M3', 'd5', 'm7']
    elif chordName == 'major ninth':
        return ['P1', 'M3', 'P5', 'M7', 'M9']
    elif chordName == 'minor ninth':
        return ['P1', 'm3', 'P5', 'm7', 'M9']
    elif chordName == 'dominant ninth':
        return ['P1', 'M3', 'P5', 'm7', 'M9']
    elif chordName == 'dominant minor ninth':
        return ['P1', 'M3', 'P5', 'm7', 'm9']
    elif chordName == 'minor major ninth':
        return ['P1', 'm3', 'P5', 'M7', 'M9']
    elif chordName == 'augmented major ninth':
        return ['P1', 'M3', 'A5', 'M7', 'M9']
    elif chordName == 'augmented dominant ninth':
        return ['P1', 'M3', 'A5', 'm7', 'M9']
    elif chordName == 'half diminished ninth':
        return ['P1', 'm3', 'd5', 'm7', 'M9']
    elif chordName == 'half diminished minor ninth':
        return ['P1', 'm3', 'd5', 'm7', 'm9']
    elif chordName == 'diminished ninth':
        return ['P1', 'm3', 'd5', 'd7', 'M9']
    elif chordName == 'diminished minor ninth':
        return ['P1', 'm3', 'd5', 'd7', 'm9']
    elif chordName == 'eleventh':
        return ['P1', 'M3', 'P5', 'm7', 'M9', 'P11']
    elif chordName == 'minor eleventh':
        return ['P1', 'm3', 'P5', 'm7', 'M9', 'P11']    
    elif chordName == 'major eleventh':
        return ['P1', 'M3', 'P5', 'M7', 'M9', 'P11']
    elif chordName == 'minor major eleventh':
        return ['P1', 'm3', 'P5', 'M7', 'M9', 'P11']
    elif chordName == 'augmented major eleventh':
        return ['P1', 'M3', 'A5', 'M7', 'M9', 'P11']
    elif chordName == 'augmented eleventh':
        return ['P1', 'M3', 'A5', 'm7', 'M9', 'P11']
    elif chordName == 'half diminished eleventh':
        return ['P1', 'm3', 'd5', 'm7', 'M9', 'P11']
    elif chordName == 'diminished eleventh':
        return ['P1', 'm3', 'd5', 'd7', 'M9', 'P11']
    elif chordName == 'major thirteenth':
        return ['P1', 'M3', 'P5', 'M7', 'M9', 'P11', 'M13']
    elif chordName == 'minor thirteenth':
        return ['P1', 'm3', 'P5', 'm7', 'M9', 'P11', 'M13']
    elif chordName == 'dominant thirteenth':
        return ['P1', 'M3', 'P5', 'm7', 'M9', 'P11', 'M13']
    elif chordName == 'minor major thirteenth':
        return ['P1', 'm3', 'P5', 'M7', 'M9', 'P11', 'M13']
    elif chordName == 'augmented major thirteenth':
        return ['P1', 'M3', 'A5', 'M7', 'M9', 'P11', 'M13']
    elif chordName == 'augmented thirteenth':
        return ['P1', 'M3', 'A5', 'm7', 'M9', 'P11', 'M13']
    elif chordName == 'half diminished thirteenth':
        return ['P1', 'm3', 'd5', 'm7', 'M9', 'P11', 'M13']
    elif chordName == 'diminished thirteenth':
        return ['P1', 'm3', 'd5', 'd7', 'M9', 'P11', 'M13']
    elif chordName == 'diminished minor thirteenth':
        return ['P1', 'm3', 'd5', 'd7', 'm9', 'P11', 'M13']
    elif chordName == 'minor sixth':
        return ['P1', 'm3', 'P5', 'M6']
    elif chordName == 'major sixth':
        return ['P1', 'M3', 'P5', 'M6']
    else:
        raise ValueError(f"Unknown chord type: {chordName}")

# %%
def noteToMidi(note): # Note is of format C -> default to C/4, or C/4
    note = note.strip().replace('♯', '#').replace('♭', 'b').replace('𝄫', 'bb').replace('𝄪', '##')
    if '/' in note:
        note, octave = note.split('/')
        octave = int(octave)
    else:
        octave = 4  # Default octave if not specified
    
    noteToMidiMap = {
        'C': 0, 'D': 2, 'E': 4, 'F': 5, 'G': 7, 'A': 9, 'B': 11,
        'C#': 1, 'D#': 3, 'F#': 6, 'G#': 8, 'A#': 10,
        'Bb': 10, 'Cb': 11, 'B#': 0, 'E#': 5,
    }
    
    if note not in noteToMidiMap:
        raise ValueError(f"Unknown note: {note}")
    
    midiNote = noteToMidiMap[note] + (octave + 1) * 12
    return midiNote

def midiToNote(midiNote):
    if not isinstance(midiNote, int) or midiNote < 0:
        raise ValueError("MIDI note must be a non-negative integer")
    
    octave = (midiNote // 12) - 1
    noteIndex = midiNote % 12
    
    indexToNoteMap = {
        0: 'C', 1: 'C#', 2: 'D', 3: 'D#', 4: 'E', 
        5: 'F', 6: 'F#', 7: 'G', 8: 'G#', 9: 'A', 
        10: 'A#', 11: 'B'
    }
    
    if noteIndex not in indexToNoteMap:
        raise ValueError(f"Unknown MIDI note index: {noteIndex}")
    
    return f"{indexToNoteMap[noteIndex]}/{octave}"

# %%
chordSuffixesCommon = ['Major', 'Minor', '7', '5', 'dim', 'dim7', 'aug', 'sus2', 'sus4', 'maj7', 'm7', '7sus4', '7b9']
chordSuffixesTriads = ['M', 'm', '+', 'o', 'b5', 'sus4', 'sus2']
chordSuffixesSevenths = ['7', 'M7','mM7', 'm7', '+M7','+7','ø', 'o7', '7b5','m6', '6']
chordSuffixesNines = ['M9', '9', '7b9', 'm9', 'mM9', '+M9', '+9', 'ø9', 'o9', 'ob9']
chordSuffixesElevens = ['11', 'm11', 'M11', 'mM11', '+M11', '+11', 'ø11', 'o11']
chordSuffixesThirteens = ['13', 'm13', 'M13', 'mM13', '+M13', '+13', 'ø13']

chords = {
    'common': chordSuffixesCommon,
    'triads': chordSuffixesTriads,
    'sevenths': chordSuffixesSevenths,
    'nines': chordSuffixesNines,
    'elevens': chordSuffixesElevens,
    'thirteens': chordSuffixesThirteens
}

for key, value in chords.items():
    print(f"{key.capitalize()} Chords: {len(value)}")

totalNumber = sum(len(value) for value in chords.values())
print(f"Total number of chord suffixes: {totalNumber}")
# Out:
# Common Chords: 13
# Triads Chords: 7
# Sevenths Chords: 11
# Nines Chords: 10
# Elevens Chords: 8
# Thirteens Chords: 7
# Total number of chord suffixes: 56

# %%
def processChord(chordName):
    # print(f"Processing chord: {chordName}")
    chord = resolveChord(chordName)
    rootNote = chord['rootNote']
    chordType = chord['chordType']
    suspended = chord['suspended']
    addedTone = chord['addedTone']
    bassNote = chord['bassNote']
    noTone = chord['noTone']
    flatNotes = chord['flatNotes']
    sharpNotes = chord['sharpNotes']
    
    intervals = chordToIntervals(chordType)
    
    rootMidi = noteToMidi(rootNote)
    
    # if bassNote:
    #     bassMidi = noteToMidi(bassNote)
    #     bassInterval = bassMidi - rootMidi
    #     if bassInterval < 0:
    #         bassInterval += 12
    #     intervals.append(midiToNote(bassMidi))
        
    if suspended:
        if suspended == 'sus2':
            intervals[1] = 'M2'
        elif suspended == 'sus4':
            intervals[1] = 'P4'
            
    if flatNotes:
        for note in flatNotes:
            if note == 3:
                intervals[1] = 'm3'
            elif note == 5:
                intervals[2] = 'd5'
            elif note == 7:
                intervals[3] = 'm7'
    if sharpNotes:
        for note in sharpNotes:
            if note == 3:
                intervals[1] = 'M3'
            elif note == 5:
                intervals[2] = 'A5'
            elif note == 7:
                intervals[3] = 'M7'
            
    if addedTone:
        intervals.append(f'M{addedTone}')
    if noTone:
        intervals = [i for i in intervals if noTone not in i]
    
    notes = []
    for interval in intervals:
        semitones = intervalToSemitones(interval)
        noteMidi = rootMidi + semitones
        if noteMidi >= 128:  # MIDI note range is 0-127
            raise ValueError("MIDI note out of range")
        notes.append(midiToNote(noteMidi))
    
    if bassNote:
        bassMidi = noteToMidi(bassNote)
        bassInterval = bassMidi - rootMidi
        if bassInterval < 0:
            bassInterval += 12
        notes.append(midiToNote(bassMidi))
    
    return {
        'root': rootMidi,
        'rootNote': rootNote,
        'chordType': chordType,
        'suspended': suspended,
        'addedTone': addedTone,
        'noTone': noTone,
        'intervals': intervals,
        'rootMidi': rootMidi,
        'notes': notes
    }

# %%
for chord in chordSuffixesCommon:
    # processed = processChord("C"+chord)
    resolved = processChord("C"+chord)
    resolvedType = resolved['chordType']
    # intervals = chordToIntervals(resolvedType)
    rootNote = resolved['rootNote']
    # rootMidi = noteToMidi(rootNote)
    # intervals_ = [rootMidi + intervalToSemitones(interval) for interval in intervals]
    # intervals_ = [midiToNote(note)[:-2] for note in intervals_]
    
    print(f"{chord:16s}: {resolvedType:32s} ({rootNote}): {', '.join(resolved['notes'])}")
    
    # print(f"{chord}: {}")
# Out:
# Major           : Major Triad                      (C): C/4, E/4, G/4
# Minor           : Minor Triad                      (C): C/4, D#/4, G/4
# 7               : Dominant Seventh                 (C): C/4, E/4, G/4, A#/4
# 5               : Power Chord                      (C): C/4, G/4
# dim             : Diminished Triad                 (C): C/4, D#/4, F#/4
# dim7            : Diminished Seventh               (C): C/4, D#/4, F#/4, A/4
# aug             : Augmented Triad                  (C): C/4, E/4, G#/4
# sus2            : Major Triad                      (C): C/4, D/4, G/4
# sus4            : Major Triad                      (C): C/4, F/4, G/4
# maj7            : Major Seventh                    (C): C/4, E/4, G/4, B/4
# m7              : Minor Seventh                    (C): C/4, D#/4, G/4, A#/4
# 7sus4           : Dominant Seventh                 (C): C/4, F/4, G/4, A#/4
# 7b9             : Dominant minor Ninth             (C): C/4, E/4, G/4, A#/4, C#/5

# %%
midiToNote(noteToMidi('C#/4'))[:-2]
# Out:
# 'C#'

# %%
scale = scales[0]['scales']['Major'][0]
scaleNotes = getScale('C', scale['intervals'])
print(f"Scale Notes for {scale['name']}: {scaleNotes}")



for ic, chord in enumerate(chords['common']):
    chordNotes = processChord('C' + chord)['notes']
    print(chordNotes)
# Out:
# Scale Notes for Ionian: ['C', 'D', 'E', 'F', 'G', 'A', 'B', 'C']
# ['C/4', 'E/4', 'G/4']
# ['C/4', 'D#/4', 'G/4']
# ['C/4', 'E/4', 'G/4', 'A#/4']
# ['C/4', 'G/4']
# ['C/4', 'D#/4', 'F#/4']
# ['C/4', 'D#/4', 'F#/4', 'A/4']
# ['C/4', 'E/4', 'G#/4']
# ['C/4', 'D/4', 'G/4']
# ['C/4', 'F/4', 'G/4']
# ['C/4', 'E/4', 'G/4', 'B/4']
# ['C/4', 'D#/4', 'G/4', 'A#/4']
# ['C/4', 'F/4', 'G/4', 'A#/4']
# ['C/4', 'E/4', 'G/4', 'A#/4', 'C#/5']

# %%
def matchChord(inputChord, verbose = False):
    if verbose:
        print(f"Matching Chord: {inputChord}")
    candidates  = []
    for chordGroup in chords:
        if len(inputChord) == 3 and chordGroup != 'triads': 
            continue
        if len(inputChord) == 4 and chordGroup != 'sevenths':
            continue
        if verbose:
            print(f"{chordGroup.capitalize()} Chords:")
        for chord in chords[chordGroup]:
            
            chordNotes = processChord(inputChord[0] + chord)['notes']
            chordNotes = [note[:-2] for note in chordNotes]  # Remove octave information
            if verbose:
                print(f"  {chord:16s}: {', '.join(chordNotes)}")
            if len(chordNotes)  == len(inputChord):
                if chordNotes == inputChord:
                    # print(f"  {chord:16s} is a synthetic I chord in {scale['name']} scale")
                    candidates.append(chord)
        
        if len(candidates) == 0:
            if verbose:
                print(f"No matches found in {chordGroup.capitalize()} Chords")
                print('Trying sus2')
            for chord in chords[chordGroup]:
                if 'sus' in chord: continue
                if chord == 'b5': continue
                chordNotes = processChord(inputChord[0] + chord + 'sus2')['notes']
                chordNotes = [note[:-2] for note in chordNotes]
                if verbose:
                    print(f"  {chord:16s}sus2: {', '.join(chordNotes)}")
                if len(chordNotes) == len(inputChord):
                    if chordNotes == inputChord:
                        # print(f"  {chord:16s}sus2 is a synthetic I chord in {scale['name']} scale")
                        candidates.append(chord + 'sus2')
        if len(candidates) == 0:
            if verbose:
                print(f"No matches found in {chordGroup.capitalize()} Chords with sus2")
                print('Trying sus4')
            for chord in chords[chordGroup]:
                # print('Current Chord: ', chord)
                if 'sus' in chord: continue
                if chord == 'b5': continue
                chordNotes = processChord(inputChord[0] + chord + 'sus4')['notes']
                chordNotes = [note[:-2] for note in chordNotes]
                if verbose:
                    print(f"  {chord:16s}sus4: {', '.join(chordNotes)}")
                if len(chordNotes) == len(inputChord):
                    if chordNotes == inputChord:
                        # print(f"  {chord:16s}sus4 is a synthetic I chord in {scale['name']} scale")
                        candidates.append(chord + 'sus4')
        # print()
        
    # print(candidates)
    return candidates
def generateSyntheticChords(scale, length = 3):
    scaleNotes = getScale('C', scale['intervals'])
    syntheticChords = []
    for i in range(len(scaleNotes)-1):
        chordNotes = []
        for j in range(length):
            chordNotes.append(scaleNotes[(i + j * 2) % (len(scaleNotes)-1)])
        # chordNotes = [scaleNotes[i], scaleNotes[(i + 2) % (len(scaleNotes) - 1)], scaleNotes[(i + 4) % (len(scaleNotes)-1)]]
        syntheticChords.append(chordNotes)
    return syntheticChords

# %%
syntheticIChord = [scaleNotes[0], scaleNotes[2], scaleNotes[4]]
# print(f"Synthetic I Chord for {scale['name']}: {syntheticIChord}")

# %%
scale = scales[0]['scales']['Double Harmonic Major'][2]
# print(scale)
print(f"Scale: {scale['name']}, Intervals: {scale['intervals']}")

scaleNotes = getScale('C', scale['intervals'])
print(f"Scale Notes for {scale['name']}: {scaleNotes}")

syntheticChords = generateSyntheticChords(scale, 3)

print(f"Synthetic Chords for {scale['name']}:")
print(f'Scale Notes: {scaleNotes}')

for i, chord in enumerate(syntheticChords):
    print(f"Synthetic Chord {i+1} for {scale['name']}: {chord}")
    
print('\n\n---------------------------------\n\n')
for chord in syntheticChords:
    matchedChords = matchChord(chord, verbose=False)
    if matchedChords:
        print(f"Matched Chords for {chord}: {matchedChords}")
    else:
        print(f"No matches found for {chord}")
        matchChord(chord, verbose=True)
# Out:
# Scale: Ultraphrygian, Intervals: ['H', 'W', 'H', 'A', 'H', 'H', 'A']
# Scale Notes for Ultraphrygian: ['C', 'C#', 'D#', 'E', 'G', 'G#', 'A', 'C']
# Synthetic Chords for Ultraphrygian:
# Scale Notes: ['C', 'C#', 'D#', 'E', 'G', 'G#', 'A', 'C']
# Synthetic Chord 1 for Ultraphrygian: ['C', 'D#', 'G']
# Synthetic Chord 2 for Ultraphrygian: ['C#', 'E', 'G#']
# Synthetic Chord 3 for Ultraphrygian: ['D#', 'G', 'A']
# Synthetic Chord 4 for Ultraphrygian: ['E', 'G#', 'C']
# Synthetic Chord 5 for Ultraphrygian: ['G', 'A', 'C#']
# Synthetic Chord 6 for Ultraphrygian: ['G#', 'C', 'D#']
# Synthetic Chord 7 for Ultraphrygian: ['A', 'C#', 'E']
#
#
# ---------------------------------
#
#
# Matched Chords for ['C', 'D#', 'G']: ['m']
# Matched Chords for ['C#', 'E', 'G#']: ['m']
# Matched Chords for ['D#', 'G', 'A']: ['b5']
# Matched Chords for ['E', 'G#', 'C']: ['+']
# Matched Chords for ['G', 'A', 'C#']: ['osus2']
# Matched Chords for ['G#', 'C', 'D#']: ['M']
# Matched Chords for ['A', 'C#', 'E']: ['M']

# %%
def iterateScale(scaleName, length = 3):
    localScales = scales[0]['scales'][scaleName]
    for i in range(len(localScales)):
        scale = localScales[i]
        # print(scale)
        print(f"Scale: {scale['name']}, Intervals: {scale['intervals']}")

        scaleNotes = getScale('C', scale['intervals'])
        # print(f"Scale Notes for {scale['name']}: {scaleNotes}")

        syntheticChords = generateSyntheticChords(scale, length)

        # print(f"Synthetic Chords for {scale['name']}:")
        # print(f'Scale Notes: {scaleNotes}')

        # for i, chord in enumerate(syntheticChords):
            # print(f"Synthetic Chord {i+1} for {scale['name']}: {chord}")
            
        # print('\n\n---------------------------------\n\n')
        for ic, chord in enumerate(syntheticChords):
            matchedChords = matchChord(chord, verbose=False)
            if matchedChords:
                print(f"Matched Chords for [{ic:2}] {chord}: {matchedChords}")
            else:
                print(f"No matches found for [{ic:2}] {chord}")
                matchChord(chord, verbose=True)
                raise ValueError(f"No matches found for {chord} in {scale['name']} scale")
                
for scaleName in scales[0]['scales'].keys():
    print(f"Iterating Scale: {scaleName}")
    iterateScale(scaleName, 4)
# Out:
# Iterating Scale: Major
# Scale: Ionian, Intervals: ['W', 'W', 'H', 'W', 'W', 'W', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G', 'B']: ['M7']
# Matched Chords for [ 1] ['D', 'F', 'A', 'C']: ['m7']
# Matched Chords for [ 2] ['E', 'G', 'B', 'D']: ['m7']
# Matched Chords for [ 3] ['F', 'A', 'C', 'E']: ['M7']
# Matched Chords for [ 4] ['G', 'B', 'D', 'F']: ['7']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G']: ['m7']
# Matched Chords for [ 6] ['B', 'D', 'F', 'A']: ['ø']
# Scale: Dorian, Intervals: ['W', 'H', 'W', 'W', 'W', 'H', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'A#']: ['m7']
# Matched Chords for [ 1] ['D', 'F', 'A', 'C']: ['m7']
# Matched Chords for [ 2] ['D#', 'G', 'A#', 'D']: ['M7']
# Matched Chords for [ 3] ['F', 'A', 'C', 'D#']: ['7']
# Matched Chords for [ 4] ['G', 'A#', 'D', 'F']: ['m7']
# Matched Chords for [ 5] ['A', 'C', 'D#', 'G']: ['ø']
# Matched Chords for [ 6] ['A#', 'D', 'F', 'A']: ['M7']
# Scale: Phrygian, Intervals: ['H', 'W', 'W', 'W', 'H', 'W', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'A#']: ['m7']
# Matched Chords for [ 1] ['C#', 'F', 'G#', 'C']: ['M7']
# Matched Chords for [ 2] ['D#', 'G', 'A#', 'C#']: ['7']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'D#']: ['m7']
# Matched Chords for [ 4] ['G', 'A#', 'C#', 'F']: ['ø']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'G']: ['M7']
# Matched Chords for [ 6] ['A#', 'C#', 'F', 'G#']: ['m7']
# Scale: Lydian, Intervals: ['W', 'W', 'W', 'H', 'W', 'H', 'W']
# Matched Chords for [ 0] ['C', 'E', 'G', 'A#']: ['7']
# Matched Chords for [ 1] ['D', 'F#', 'A', 'C']: ['7']
# Matched Chords for [ 2] ['E', 'G', 'A#', 'D']: ['ø']
# Matched Chords for [ 3] ['F#', 'A', 'C', 'E']: ['ø']
# Matched Chords for [ 4] ['G', 'A#', 'D', 'F#']: ['mM7']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G']: ['m7']
# Matched Chords for [ 6] ['A#', 'D', 'F#', 'A']: ['+M7']
# Scale: Mixolydian, Intervals: ['W', 'W', 'H', 'W', 'W', 'H', 'W']
# Matched Chords for [ 0] ['C', 'E', 'G', 'A#']: ['7']
# Matched Chords for [ 1] ['D', 'F', 'A', 'C']: ['m7']
# Matched Chords for [ 2] ['E', 'G', 'A#', 'D']: ['ø']
# Matched Chords for [ 3] ['F', 'A', 'C', 'E']: ['M7']
# Matched Chords for [ 4] ['G', 'A#', 'D', 'F']: ['m7']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G']: ['m7']
# Matched Chords for [ 6] ['A#', 'D', 'F', 'A']: ['M7']
# Scale: Aeolian, Intervals: ['W', 'H', 'W', 'W', 'H', 'W', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'A#']: ['m7']
# Matched Chords for [ 1] ['D', 'F', 'G#', 'C']: ['ø']
# Matched Chords for [ 2] ['D#', 'G', 'A#', 'D']: ['M7']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'D#']: ['m7']
# Matched Chords for [ 4] ['G', 'A#', 'D', 'F']: ['m7']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'G']: ['M7']
# Matched Chords for [ 6] ['A#', 'D', 'F', 'G#']: ['7']
# Scale: Locrian, Intervals: ['H', 'W', 'W', 'H', 'W', 'W', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'F#', 'A#']: ['ø']
# Matched Chords for [ 1] ['C#', 'F', 'G#', 'C']: ['M7']
# Matched Chords for [ 2] ['D#', 'F#', 'A#', 'C#']: ['m7']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'D#']: ['m7']
# Matched Chords for [ 4] ['F#', 'A#', 'C#', 'F']: ['M7']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'F#']: ['7']
# Matched Chords for [ 6] ['A#', 'C#', 'F', 'G#']: ['m7']
# Iterating Scale: Harmonic Minor
# Scale: Harmonic Minor, Intervals: ['W', 'H', 'W', 'W', 'H', 'A', 'H']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'B']: ['mM7']
# Matched Chords for [ 1] ['D', 'F', 'G#', 'C']: ['ø']
# Matched Chords for [ 2] ['D#', 'G', 'B', 'D']: ['+M7']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'D#']: ['m7']
# Matched Chords for [ 4] ['G', 'B', 'D', 'F']: ['7']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'G']: ['M7']
# Matched Chords for [ 6] ['B', 'D', 'F', 'G#']: ['o7']
# Scale: Locrian ♮6, Intervals: ['H', 'W', 'W', 'H', 'A', 'H', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'F#', 'A#']: ['ø']
# Matched Chords for [ 1] ['C#', 'F', 'A', 'C']: ['+M7']
# Matched Chords for [ 2] ['D#', 'F#', 'A#', 'C#']: ['m7']
# Matched Chords for [ 3] ['F', 'A', 'C', 'D#']: ['7']
# Matched Chords for [ 4] ['F#', 'A#', 'C#', 'F']: ['M7']
# Matched Chords for [ 5] ['A', 'C', 'D#', 'F#']: ['o7']
# Matched Chords for [ 6] ['A#', 'C#', 'F', 'A']: ['mM7']
# Scale: Ionian ♯5, Intervals: ['W', 'W', 'H', 'A', 'H', 'W', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G#', 'B']: ['+M7']
# Matched Chords for [ 1] ['D', 'F', 'A', 'C']: ['m7']
# Matched Chords for [ 2] ['E', 'G#', 'B', 'D']: ['7']
# Matched Chords for [ 3] ['F', 'A', 'C', 'E']: ['M7']
# Matched Chords for [ 4] ['G#', 'B', 'D', 'F']: ['o7']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G#']: ['mM7']
# Matched Chords for [ 6] ['B', 'D', 'F', 'A']: ['ø']
# Scale: Ukrainian Dorian, Intervals: ['W', 'H', 'A', 'H', 'W', 'H', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'A#']: ['m7']
# Matched Chords for [ 1] ['D', 'F#', 'A', 'C']: ['7']
# Matched Chords for [ 2] ['D#', 'G', 'A#', 'D']: ['M7']
# Matched Chords for [ 3] ['F#', 'A', 'C', 'D#']: ['o7']
# Matched Chords for [ 4] ['G', 'A#', 'D', 'F#']: ['mM7']
# Matched Chords for [ 5] ['A', 'C', 'D#', 'G']: ['ø']
# Matched Chords for [ 6] ['A#', 'D', 'F#', 'A']: ['+M7']
# Scale: Phrygian Dominant, Intervals: ['H', 'A', 'H', 'W', 'H', 'W', 'W']
# Matched Chords for [ 0] ['C', 'E', 'G', 'A#']: ['7']
# Matched Chords for [ 1] ['C#', 'F', 'G#', 'C']: ['M7']
# Matched Chords for [ 2] ['E', 'G', 'A#', 'C#']: ['o7']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'E']: ['mM7']
# Matched Chords for [ 4] ['G', 'A#', 'C#', 'F']: ['ø']
# Matched Chords for [ 5] ['G#', 'C', 'E', 'G']: ['+M7']
# Matched Chords for [ 6] ['A#', 'C#', 'F', 'G#']: ['m7']
# Scale: Lydian #9, Intervals: ['A', 'H', 'W', 'H', 'W', 'W', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G', 'B']: ['M7']
# Matched Chords for [ 1] ['D#', 'F#', 'A', 'C']: ['o7']
# Matched Chords for [ 2] ['E', 'G', 'B', 'D#']: ['mM7']
# Matched Chords for [ 3] ['F#', 'A', 'C', 'E']: ['ø']
# Matched Chords for [ 4] ['G', 'B', 'D#', 'F#']: ['+M7']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G']: ['m7']
# Matched Chords for [ 6] ['B', 'D#', 'F#', 'A']: ['7']
# Scale: Super-Locrian scale 𝄫7, Intervals: ['H', 'W', 'H', 'W', 'W', 'H', 'A']
# Matched Chords for [ 0] ['C', 'D#', 'F#', 'A']: ['o7']
# Matched Chords for [ 1] ['C#', 'E', 'G#', 'C']: ['mM7']
# Matched Chords for [ 2] ['D#', 'F#', 'A', 'C#']: ['ø']
# Matched Chords for [ 3] ['E', 'G#', 'C', 'D#']: ['+M7']
# Matched Chords for [ 4] ['F#', 'A', 'C#', 'E']: ['m7']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'F#']: ['7']
# Matched Chords for [ 6] ['A', 'C#', 'E', 'G#']: ['M7']
# Iterating Scale: Harmonic Major
# Scale: Harmonic Major, Intervals: ['W', 'W', 'H', 'W', 'H', 'A', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G', 'B']: ['M7']
# Matched Chords for [ 1] ['D', 'F', 'G#', 'C']: ['ø']
# Matched Chords for [ 2] ['E', 'G', 'B', 'D']: ['m7']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'E']: ['mM7']
# Matched Chords for [ 4] ['G', 'B', 'D', 'F']: ['7']
# Matched Chords for [ 5] ['G#', 'C', 'E', 'G']: ['+M7']
# Matched Chords for [ 6] ['B', 'D', 'F', 'G#']: ['o7']
# Scale: Locrian ♮2 ♮6, Intervals: ['W', 'H', 'W', 'H', 'A', 'H', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'F#', 'A#']: ['ø']
# Matched Chords for [ 1] ['D', 'F', 'A', 'C']: ['m7']
# Matched Chords for [ 2] ['D#', 'F#', 'A#', 'D']: ['mM7']
# Matched Chords for [ 3] ['F', 'A', 'C', 'D#']: ['7']
# Matched Chords for [ 4] ['F#', 'A#', 'D', 'F']: ['+M7']
# Matched Chords for [ 5] ['A', 'C', 'D#', 'F#']: ['o7']
# Matched Chords for [ 6] ['A#', 'D', 'F', 'A']: ['M7']
# Scale: Altered Dominant ♮5, Intervals: ['H', 'W', 'H', 'A', 'H', 'W', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'A#']: ['m7']
# Matched Chords for [ 1] ['C#', 'E', 'G#', 'C']: ['mM7']
# Matched Chords for [ 2] ['D#', 'G', 'A#', 'C#']: ['7']
# Matched Chords for [ 3] ['E', 'G#', 'C', 'D#']: ['+M7']
# Matched Chords for [ 4] ['G', 'A#', 'C#', 'E']: ['o7']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'G']: ['M7']
# Matched Chords for [ 6] ['A#', 'C#', 'E', 'G#']: ['ø']
# Scale: Jazz Minor ♯4, Intervals: ['W', 'H', 'A', 'H', 'W', 'W', 'H']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'B']: ['mM7']
# Matched Chords for [ 1] ['D', 'F#', 'A', 'C']: ['7']
# Matched Chords for [ 2] ['D#', 'G', 'B', 'D']: ['+M7']
# Matched Chords for [ 3] ['F#', 'A', 'C', 'D#']: ['o7']
# Matched Chords for [ 4] ['G', 'B', 'D', 'F#']: ['M7']
# Matched Chords for [ 5] ['A', 'C', 'D#', 'G']: ['ø']
# Matched Chords for [ 6] ['B', 'D', 'F#', 'A']: ['m7']
# Scale: Mixolydian ♭2, Intervals: ['H', 'A', 'H', 'W', 'W', 'H', 'W']
# Matched Chords for [ 0] ['C', 'E', 'G', 'A#']: ['7']
# Matched Chords for [ 1] ['C#', 'F', 'A', 'C']: ['+M7']
# Matched Chords for [ 2] ['E', 'G', 'A#', 'C#']: ['o7']
# Matched Chords for [ 3] ['F', 'A', 'C', 'E']: ['M7']
# Matched Chords for [ 4] ['G', 'A#', 'C#', 'F']: ['ø']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G']: ['m7']
# Matched Chords for [ 6] ['A#', 'C#', 'F', 'A']: ['mM7']
# Scale: Lydian Augmented ♯2, Intervals: ['A', 'H', 'W', 'W', 'H', 'W', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G#', 'B']: ['+M7']
# Matched Chords for [ 1] ['D#', 'F#', 'A', 'C']: ['o7']
# Matched Chords for [ 2] ['E', 'G#', 'B', 'D#']: ['M7']
# Matched Chords for [ 3] ['F#', 'A', 'C', 'E']: ['ø']
# Matched Chords for [ 4] ['G#', 'B', 'D#', 'F#']: ['m7']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G#']: ['mM7']
# Matched Chords for [ 6] ['B', 'D#', 'F#', 'A']: ['7']
# Scale: Locrian 𝄫7, Intervals: ['H', 'W', 'W', 'H', 'W', 'H', 'A']
# Matched Chords for [ 0] ['C', 'D#', 'F#', 'A']: ['o7']
# Matched Chords for [ 1] ['C#', 'F', 'G#', 'C']: ['M7']
# Matched Chords for [ 2] ['D#', 'F#', 'A', 'C#']: ['ø']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'D#']: ['m7']
# Matched Chords for [ 4] ['F#', 'A', 'C#', 'F']: ['mM7']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'F#']: ['7']
# Matched Chords for [ 6] ['A', 'C#', 'F', 'G#']: ['+M7']
# Iterating Scale: Melodic Minor
# Scale: Melodic Minor, Intervals: ['W', 'H', 'W', 'W', 'W', 'W', 'H']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'B']: ['mM7']
# Matched Chords for [ 1] ['D', 'F', 'A', 'C']: ['m7']
# Matched Chords for [ 2] ['D#', 'G', 'B', 'D']: ['+M7']
# Matched Chords for [ 3] ['F', 'A', 'C', 'D#']: ['7']
# Matched Chords for [ 4] ['G', 'B', 'D', 'F']: ['7']
# Matched Chords for [ 5] ['A', 'C', 'D#', 'G']: ['ø']
# Matched Chords for [ 6] ['B', 'D', 'F', 'A']: ['ø']
# Scale: Dorian ♭2, Intervals: ['H', 'W', 'W', 'W', 'W', 'H', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'A#']: ['m7']
# Matched Chords for [ 1] ['C#', 'F', 'A', 'C']: ['+M7']
# Matched Chords for [ 2] ['D#', 'G', 'A#', 'C#']: ['7']
# Matched Chords for [ 3] ['F', 'A', 'C', 'D#']: ['7']
# Matched Chords for [ 4] ['G', 'A#', 'C#', 'F']: ['ø']
# Matched Chords for [ 5] ['A', 'C', 'D#', 'G']: ['ø']
# Matched Chords for [ 6] ['A#', 'C#', 'F', 'A']: ['mM7']
# Scale: Lydian Augmented, Intervals: ['W', 'W', 'W', 'W', 'H', 'W', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G#', 'B']: ['+M7']
# Matched Chords for [ 1] ['D', 'F#', 'A', 'C']: ['7']
# Matched Chords for [ 2] ['E', 'G#', 'B', 'D']: ['7']
# Matched Chords for [ 3] ['F#', 'A', 'C', 'E']: ['ø']
# Matched Chords for [ 4] ['G#', 'B', 'D', 'F#']: ['ø']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G#']: ['mM7']
# Matched Chords for [ 6] ['B', 'D', 'F#', 'A']: ['m7']
# Scale: Acoustic scale, Intervals: ['W', 'W', 'W', 'H', 'W', 'H', 'W']
# Matched Chords for [ 0] ['C', 'E', 'G', 'A#']: ['7']
# Matched Chords for [ 1] ['D', 'F#', 'A', 'C']: ['7']
# Matched Chords for [ 2] ['E', 'G', 'A#', 'D']: ['ø']
# Matched Chords for [ 3] ['F#', 'A', 'C', 'E']: ['ø']
# Matched Chords for [ 4] ['G', 'A#', 'D', 'F#']: ['mM7']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G']: ['m7']
# Matched Chords for [ 6] ['A#', 'D', 'F#', 'A']: ['+M7']
# Scale: Aeolian dominant, Intervals: ['W', 'W', 'H', 'W', 'H', 'W', 'W']
# Matched Chords for [ 0] ['C', 'E', 'G', 'A#']: ['7']
# Matched Chords for [ 1] ['D', 'F', 'G#', 'C']: ['ø']
# Matched Chords for [ 2] ['E', 'G', 'A#', 'D']: ['ø']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'E']: ['mM7']
# Matched Chords for [ 4] ['G', 'A#', 'D', 'F']: ['m7']
# Matched Chords for [ 5] ['G#', 'C', 'E', 'G']: ['+M7']
# Matched Chords for [ 6] ['A#', 'D', 'F', 'G#']: ['7']
# Scale: Half Diminished, Intervals: ['W', 'H', 'W', 'H', 'W', 'W', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'F#', 'A#']: ['ø']
# Matched Chords for [ 1] ['D', 'F', 'G#', 'C']: ['ø']
# Matched Chords for [ 2] ['D#', 'F#', 'A#', 'D']: ['mM7']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'D#']: ['m7']
# Matched Chords for [ 4] ['F#', 'A#', 'D', 'F']: ['+M7']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'F#']: ['7']
# Matched Chords for [ 6] ['A#', 'D', 'F', 'G#']: ['7']
# Scale: Altered Scale, Intervals: ['H', 'W', 'H', 'W', 'W', 'W', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'F#', 'A#']: ['ø']
# Matched Chords for [ 1] ['C#', 'E', 'G#', 'C']: ['mM7']
# Matched Chords for [ 2] ['D#', 'F#', 'A#', 'C#']: ['m7']
# Matched Chords for [ 3] ['E', 'G#', 'C', 'D#']: ['+M7']
# Matched Chords for [ 4] ['F#', 'A#', 'C#', 'E']: ['7']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'F#']: ['7']
# Matched Chords for [ 6] ['A#', 'C#', 'E', 'G#']: ['ø']
# Iterating Scale: Double Harmonic Major
# Scale: Double Harmonic Major, Intervals: ['H', 'A', 'H', 'W', 'H', 'A', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G', 'B']: ['M7']
# Matched Chords for [ 1] ['C#', 'F', 'G#', 'C']: ['M7']
# Matched Chords for [ 2] ['E', 'G', 'B', 'C#']: ['m6']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'E']: ['mM7']
# Matched Chords for [ 4] ['G', 'B', 'C#', 'F']: ['7b5']
# Matched Chords for [ 5] ['G#', 'C', 'E', 'G']: ['+M7']
# Matched Chords for [ 6] ['B', 'C#', 'F', 'G#']: ['o7sus2']
# Scale: Lydian ♯2 ♯6, Intervals: ['A', 'H', 'W', 'H', 'A', 'H', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G', 'B']: ['M7']
# Matched Chords for [ 1] ['D#', 'F#', 'A#', 'C']: ['m6']
# Matched Chords for [ 2] ['E', 'G', 'B', 'D#']: ['mM7']
# Matched Chords for [ 3] ['F#', 'A#', 'C', 'E']: ['7b5']
# Matched Chords for [ 4] ['G', 'B', 'D#', 'F#']: ['+M7']
# Matched Chords for [ 5] ['A#', 'C', 'E', 'G']: ['o7sus2']
# Matched Chords for [ 6] ['B', 'D#', 'F#', 'A#']: ['M7']
# Scale: Ultraphrygian, Intervals: ['H', 'W', 'H', 'A', 'H', 'H', 'A']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'A']: ['m6']
# Matched Chords for [ 1] ['C#', 'E', 'G#', 'C']: ['mM7']
# Matched Chords for [ 2] ['D#', 'G', 'A', 'C#']: ['7b5']
# Matched Chords for [ 3] ['E', 'G#', 'C', 'D#']: ['+M7']
# Matched Chords for [ 4] ['G', 'A', 'C#', 'E']: ['o7sus2']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'G']: ['M7']
# Matched Chords for [ 6] ['A', 'C#', 'E', 'G#']: ['M7']
# Scale: Hungarian, Intervals: ['W', 'H', 'A', 'H', 'H', 'A', 'H']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'B']: ['mM7']
# Matched Chords for [ 1] ['D', 'F#', 'G#', 'C']: ['7b5']
# Matched Chords for [ 2] ['D#', 'G', 'B', 'D']: ['+M7']
# Matched Chords for [ 3] ['F#', 'G#', 'C', 'D#']: ['o7sus2']
# Matched Chords for [ 4] ['G', 'B', 'D', 'F#']: ['M7']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'G']: ['M7']
# Matched Chords for [ 6] ['B', 'D', 'F#', 'G#']: ['m6']
# Scale: Oriental, Intervals: ['H', 'A', 'H', 'H', 'A', 'H', 'W']
# Matched Chords for [ 0] ['C', 'E', 'F#', 'A#']: ['7b5']
# Matched Chords for [ 1] ['C#', 'F', 'A', 'C']: ['+M7']
# Matched Chords for [ 2] ['E', 'F#', 'A#', 'C#']: ['o7sus2']
# Matched Chords for [ 3] ['F', 'A', 'C', 'E']: ['M7']
# Matched Chords for [ 4] ['F#', 'A#', 'C#', 'F']: ['M7']
# Matched Chords for [ 5] ['A', 'C', 'E', 'F#']: ['m6']
# Matched Chords for [ 6] ['A#', 'C#', 'F', 'A']: ['mM7']
# Scale: Ionian ♯2 ♯5, Intervals: ['A', 'H', 'H', 'A', 'H', 'W', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G#', 'B']: ['+M7']
# Matched Chords for [ 1] ['D#', 'F', 'A', 'C']: ['o7sus2']
# Matched Chords for [ 2] ['E', 'G#', 'B', 'D#']: ['M7']
# Matched Chords for [ 3] ['F', 'A', 'C', 'E']: ['M7']
# Matched Chords for [ 4] ['G#', 'B', 'D#', 'F']: ['m6']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G#']: ['mM7']
# Matched Chords for [ 6] ['B', 'D#', 'F', 'A']: ['7b5']
# Scale: Locrian 𝄫3 𝄫7, Intervals: ['H', 'H', 'A', 'H', 'W', 'H', 'A']
# Matched Chords for [ 0] ['C', 'D', 'F#', 'A']: ['o7sus2']
# Matched Chords for [ 1] ['C#', 'F', 'G#', 'C']: ['M7']
# Matched Chords for [ 2] ['D', 'F#', 'A', 'C#']: ['M7']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'D']: ['m6']
# Matched Chords for [ 4] ['F#', 'A', 'C#', 'F']: ['mM7']
# Matched Chords for [ 5] ['G#', 'C', 'D', 'F#']: ['7b5']
# Matched Chords for [ 6] ['A', 'C#', 'F', 'G#']: ['+M7']
# Iterating Scale: Neapolitan Major
# Scale: Neapolitan Major, Intervals: ['H', 'W', 'W', 'W', 'W', 'W', 'H']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'B']: ['mM7']
# Matched Chords for [ 1] ['C#', 'F', 'A', 'C']: ['+M7']
# Matched Chords for [ 2] ['D#', 'G', 'B', 'C#']: ['+7']
# Matched Chords for [ 3] ['F', 'A', 'C', 'D#']: ['7']
# Matched Chords for [ 4] ['G', 'B', 'C#', 'F']: ['7b5']
# Matched Chords for [ 5] ['A', 'C', 'D#', 'G']: ['ø']
# Matched Chords for [ 6] ['B', 'C#', 'F', 'A']: ['øsus2', '7b5sus2']
# Scale: Leading Whole Tone, Intervals: ['W', 'W', 'W', 'W', 'W', 'H', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G#', 'B']: ['+M7']
# Matched Chords for [ 1] ['D', 'F#', 'A#', 'C']: ['+7']
# Matched Chords for [ 2] ['E', 'G#', 'B', 'D']: ['7']
# Matched Chords for [ 3] ['F#', 'A#', 'C', 'E']: ['7b5']
# Matched Chords for [ 4] ['G#', 'B', 'D', 'F#']: ['ø']
# Matched Chords for [ 5] ['A#', 'C', 'E', 'G#']: ['øsus2', '7b5sus2']
# Matched Chords for [ 6] ['B', 'D', 'F#', 'A#']: ['mM7']
# Scale: Lydian Augmented Dominant, Intervals: ['W', 'W', 'W', 'W', 'H', 'H', 'W']
# Matched Chords for [ 0] ['C', 'E', 'G#', 'A#']: ['+7']
# Matched Chords for [ 1] ['D', 'F#', 'A', 'C']: ['7']
# Matched Chords for [ 2] ['E', 'G#', 'A#', 'D']: ['7b5']
# Matched Chords for [ 3] ['F#', 'A', 'C', 'E']: ['ø']
# Matched Chords for [ 4] ['G#', 'A#', 'D', 'F#']: ['øsus2', '7b5sus2']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G#']: ['mM7']
# Matched Chords for [ 6] ['A#', 'D', 'F#', 'A']: ['+M7']
# Scale: Lydian Dominant ♭6, Intervals: ['W', 'W', 'W', 'H', 'H', 'W', 'W']
# Matched Chords for [ 0] ['C', 'E', 'G', 'A#']: ['7']
# Matched Chords for [ 1] ['D', 'F#', 'G#', 'C']: ['7b5']
# Matched Chords for [ 2] ['E', 'G', 'A#', 'D']: ['ø']
# Matched Chords for [ 3] ['F#', 'G#', 'C', 'E']: ['øsus2', '7b5sus2']
# Matched Chords for [ 4] ['G', 'A#', 'D', 'F#']: ['mM7']
# Matched Chords for [ 5] ['G#', 'C', 'E', 'G']: ['+M7']
# Matched Chords for [ 6] ['A#', 'D', 'F#', 'G#']: ['+7']
# Scale: Major Locrian, Intervals: ['W', 'W', 'H', 'H', 'W', 'W', 'W']
# Matched Chords for [ 0] ['C', 'E', 'F#', 'A#']: ['7b5']
# Matched Chords for [ 1] ['D', 'F', 'G#', 'C']: ['ø']
# Matched Chords for [ 2] ['E', 'F#', 'A#', 'D']: ['øsus2', '7b5sus2']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'E']: ['mM7']
# Matched Chords for [ 4] ['F#', 'A#', 'D', 'F']: ['+M7']
# Matched Chords for [ 5] ['G#', 'C', 'E', 'F#']: ['+7']
# Matched Chords for [ 6] ['A#', 'D', 'F', 'G#']: ['7']
# Scale: Half-Diminished ♭4, Intervals: ['W', 'H', 'H', 'W', 'W', 'W', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'F#', 'A#']: ['ø']
# Matched Chords for [ 1] ['D', 'E', 'G#', 'C']: ['øsus2', '7b5sus2']
# Matched Chords for [ 2] ['D#', 'F#', 'A#', 'D']: ['mM7']
# Matched Chords for [ 3] ['E', 'G#', 'C', 'D#']: ['+M7']
# Matched Chords for [ 4] ['F#', 'A#', 'D', 'E']: ['+7']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'F#']: ['7']
# Matched Chords for [ 6] ['A#', 'D', 'E', 'G#']: ['7b5']
# Scale: Altered Dominant 𝄫3, Intervals: ['H', 'H', 'W', 'W', 'W', 'W', 'W']
# Matched Chords for [ 0] ['C', 'D', 'F#', 'A#']: ['øsus2', '7b5sus2']
# Matched Chords for [ 1] ['C#', 'E', 'G#', 'C']: ['mM7']
# Matched Chords for [ 2] ['D', 'F#', 'A#', 'C#']: ['+M7']
# Matched Chords for [ 3] ['E', 'G#', 'C', 'D']: ['+7']
# Matched Chords for [ 4] ['F#', 'A#', 'C#', 'E']: ['7']
# Matched Chords for [ 5] ['G#', 'C', 'D', 'F#']: ['7b5']
# Matched Chords for [ 6] ['A#', 'C#', 'E', 'G#']: ['ø']
# Iterating Scale: Neapolitan Minor
# Scale: Neapolitan Minor, Intervals: ['H', 'W', 'W', 'W', 'H', 'A', 'H']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'B']: ['mM7']
# Matched Chords for [ 1] ['C#', 'F', 'G#', 'C']: ['M7']
# Matched Chords for [ 2] ['D#', 'G', 'B', 'C#']: ['+7']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'D#']: ['m7']
# Matched Chords for [ 4] ['G', 'B', 'C#', 'F']: ['7b5']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'G']: ['M7']
# Matched Chords for [ 6] ['B', 'C#', 'F', 'G#']: ['o7sus2']
# Scale: Lydian ♯6, Intervals: ['W', 'W', 'W', 'H', 'A', 'H', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G', 'B']: ['M7']
# Matched Chords for [ 1] ['D', 'F#', 'A#', 'C']: ['+7']
# Matched Chords for [ 2] ['E', 'G', 'B', 'D']: ['m7']
# Matched Chords for [ 3] ['F#', 'A#', 'C', 'E']: ['7b5']
# Matched Chords for [ 4] ['G', 'B', 'D', 'F#']: ['M7']
# Matched Chords for [ 5] ['A#', 'C', 'E', 'G']: ['o7sus2']
# Matched Chords for [ 6] ['B', 'D', 'F#', 'A#']: ['mM7']
# Scale: Mixolydian Augmented, Intervals: ['W', 'W', 'H', 'A', 'H', 'H', 'W']
# Matched Chords for [ 0] ['C', 'E', 'G#', 'A#']: ['+7']
# Matched Chords for [ 1] ['D', 'F', 'A', 'C']: ['m7']
# Matched Chords for [ 2] ['E', 'G#', 'A#', 'D']: ['7b5']
# Matched Chords for [ 3] ['F', 'A', 'C', 'E']: ['M7']
# Matched Chords for [ 4] ['G#', 'A#', 'D', 'F']: ['o7sus2']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G#']: ['mM7']
# Matched Chords for [ 6] ['A#', 'D', 'F', 'A']: ['M7']
# Scale: Romani Minor, Intervals: ['W', 'H', 'A', 'H', 'H', 'W', 'W']
# Matched Chords for [ 0] ['C', 'D#', 'G', 'A#']: ['m7']
# Matched Chords for [ 1] ['D', 'F#', 'G#', 'C']: ['7b5']
# Matched Chords for [ 2] ['D#', 'G', 'A#', 'D']: ['M7']
# Matched Chords for [ 3] ['F#', 'G#', 'C', 'D#']: ['o7sus2']
# Matched Chords for [ 4] ['G', 'A#', 'D', 'F#']: ['mM7']
# Matched Chords for [ 5] ['G#', 'C', 'D#', 'G']: ['M7']
# Matched Chords for [ 6] ['A#', 'D', 'F#', 'G#']: ['+7']
# Scale: Locrian Dominant, Intervals: ['H', 'A', 'H', 'H', 'W', 'W', 'W']
# Matched Chords for [ 0] ['C', 'E', 'F#', 'A#']: ['7b5']
# Matched Chords for [ 1] ['C#', 'F', 'G#', 'C']: ['M7']
# Matched Chords for [ 2] ['E', 'F#', 'A#', 'C#']: ['o7sus2']
# Matched Chords for [ 3] ['F', 'G#', 'C', 'E']: ['mM7']
# Matched Chords for [ 4] ['F#', 'A#', 'C#', 'F']: ['M7']
# Matched Chords for [ 5] ['G#', 'C', 'E', 'F#']: ['+7']
# Matched Chords for [ 6] ['A#', 'C#', 'F', 'G#']: ['m7']
# Scale: Ionian ♯2, Intervals: ['A', 'H', 'H', 'W', 'W', 'W', 'H']
# Matched Chords for [ 0] ['C', 'E', 'G', 'B']: ['M7']
# Matched Chords for [ 1] ['D#', 'F', 'A', 'C']: ['o7sus2']
# Matched Chords for [ 2] ['E', 'G', 'B', 'D#']: ['mM7']
# Matched Chords for [ 3] ['F', 'A', 'C', 'E']: ['M7']
# Matched Chords for [ 4] ['G', 'B', 'D#', 'F']: ['+7']
# Matched Chords for [ 5] ['A', 'C', 'E', 'G']: ['m7']
# Matched Chords for [ 6] ['B', 'D#', 'F', 'A']: ['7b5']
# Scale: Ultralocrian 𝄫3, Intervals: ['H', 'H', 'W', 'W', 'W', 'H', 'A']
# Matched Chords for [ 0] ['C', 'D', 'F#', 'A']: ['o7sus2']
# Matched Chords for [ 1] ['C#', 'E', 'G#', 'C']: ['mM7']
# Matched Chords for [ 2] ['D', 'F#', 'A', 'C#']: ['M7']
# Matched Chords for [ 3] ['E', 'G#', 'C', 'D']: ['+7']
# Matched Chords for [ 4] ['F#', 'A', 'C#', 'E']: ['m7']
# Matched Chords for [ 5] ['G#', 'C', 'D', 'F#']: ['7b5']
# Matched Chords for [ 6] ['A', 'C#', 'E', 'G#']: ['M7']

# %%
processChord('Co7b5')
# Out:
# {'root': 60,
#  'rootNote': 'C',
#  'chordType': 'Diminished Seventh',
#  'suspended': None,
#  'addedTone': None,
#  'noTone': None,
#  'intervals': ['P1', 'm3', 'd5', 'd7'],
#  'rootMidi': 60,
#  'notes': ['C/4', 'D#/4', 'F#/4', 'A/4']}

# %%
for ic, c in enumerate(syntheticChords):
    print(f"Synthetic Chord {ic+1}: {c}")
    matchedChords = matchChord(c)
    if matchedChords:
        print(f"  Matches: {', '.join(matchedChords)}")
    else:
        print("  No matches found")
    print()
# Out:
# Synthetic Chord 1: ['C', 'D#', 'G']
# Matching Chord: ['C', 'D#', 'G']
# Triads Chords:
#   M               : C, E, G
#   m               : C, D#, G
#   +               : C, E, G#
#   o               : C, D#, F#
#   b5              : C, E, F#
#   sus4            : C, F, G
# Sevenths Chords:
#   7               : C, E, G, A#
#   M7              : C, E, G, B
#   mM7             : C, D#, G, B
#   m7              : C, D#, G, A#
#   +M7             : C, E, G#, B
#   +7              : C, E, G#, A#
#   ø               : C, D#, F#, A#
#   o7              : C, D#, F#, A
#   7b5             : C, E, F#, A#
# Nines Chords:
#   M9              : C, E, G, B, D
#   9               : C, E, G, A#, D
#   7b9             : C, E, G, A#, C#
#   m9              : C, D#, G, A#, D
#   mM9             : C, D#, G, B, D
#   +M9             : C, E, G#, B, D
#   +9              : C, E, G#, A#, D
#   ø9              : C, D#, F#, A#, D
#   o9              : C, D#, F#, A, D
#   ob9             : C, D#, F#, A, C#
# Elevens Chords:
#   11              : C, E, G, A#, D, F
#   m11             : C, D#, G, A#, D, F
#   M11             : C, E, G, B, D, F
#   mM11            : C, D#, G, B, D, F
#   +M11            : C, E, G#, B, D, F
#   +11             : C, E, G#, A#, D, F
#   ø11             : C, D#, F#, A#, D, F
#   o11             : C, D#, F#, A, D, F
# Thirteens Chords:
#   13              : C, E, G, A#, D, F, A
#   m13             : C, D#, G, A#, D, F, A
#   M13             : C, E, G, B, D, F, A
#   mM13            : C, D#, G, B, D, F, A
#   +M13            : C, E, G#, B, D, F, A
#   +13             : C, E, G#, A#, D, F, A
#   ø13             : C, D#, F#, A#, D, F, A
#   Matches: m
#
# Synthetic Chord 2: ['C#', 'E', 'G#']
# Matching Chord: ['C#', 'E', 'G#']
# Triads Chords:
#   M               : C#, F, G#
#   m               : C#, E, G#
#   +               : C#, F, A
#   o               : C#, E, G
#   b5              : C#, F, G
#   sus4            : C#, F#, G#
# Sevenths Chords:
#   7               : C#, F, G#, B
#   M7              : C#, F, G#, C
#   mM7             : C#, E, G#, C
#   m7              : C#, E, G#, B
#   +M7             : C#, F, A, C
#   +7              : C#, F, A, B
#   ø               : C#, E, G, B
#   o7              : C#, E, G, A#
#   7b5             : C#, F, G, B
# Nines Chords:
#   M9              : C#, F, G#, C, D#
#   9               : C#, F, G#, B, D#
#   7b9             : C#, F, G#, B, D
#   m9              : C#, E, G#, B, D#
#   mM9             : C#, E, G#, C, D#
#   +M9             : C#, F, A, C, D#
#   +9              : C#, F, A, B, D#
#   ø9              : C#, E, G, B, D#
#   o9              : C#, E, G, A#, D#
#   ob9             : C#, E, G, A#, D
# Elevens Chords:
#   11              : C#, F, G#, B, D#, F#
#   m11             : C#, E, G#, B, D#, F#
#   M11             : C#, F, G#, C, D#, F#
#   mM11            : C#, E, G#, C, D#, F#
#   +M11            : C#, F, A, C, D#, F#
#   +11             : C#, F, A, B, D#, F#
#   ø11             : C#, E, G, B, D#, F#
#   o11             : C#, E, G, A#, D#, F#
# Thirteens Chords:
#   13              : C#, F, G#, B, D#, F#, A#
#   m13             : C#, E, G#, B, D#, F#, A#
#   M13             : C#, F, G#, C, D#, F#, A#
#   mM13            : C#, E, G#, C, D#, F#, A#
#   +M13            : C#, F, A, C, D#, F#, A#
#   +13             : C#, F, A, B, D#, F#, A#
#   ø13             : C#, E, G, B, D#, F#, A#
#   Matches: m
#
# Synthetic Chord 3: ['D#', 'G', 'A']
# Matching Chord: ['D#', 'G', 'A']
# Triads Chords:
#   M               : D#, G, A#
#   m               : D#, F#, A#
#   +               : D#, G, B
#   o               : D#, F#, A
#   b5              : D#, G, A
#   sus4            : D#, G#, A#
# Sevenths Chords:
#   7               : D#, G, A#, C#
#   M7              : D#, G, A#, D
#   mM7             : D#, F#, A#, D
#   m7              : D#, F#, A#, C#
#   +M7             : D#, G, B, D
#   +7              : D#, G, B, C#
#   ø               : D#, F#, A, C#
#   o7              : D#, F#, A, C
#   7b5             : D#, G, A, C#
# Nines Chords:
#   M9              : D#, G, A#, D, F
#   9               : D#, G, A#, C#, F
#   7b9             : D#, G, A#, C#, E
#   m9              : D#, F#, A#, C#, F
#   mM9             : D#, F#, A#, D, F
#   +M9             : D#, G, B, D, F
#   +9              : D#, G, B, C#, F
#   ø9              : D#, F#, A, C#, F
#   o9              : D#, F#, A, C, F
#   ob9             : D#, F#, A, C, E
# Elevens Chords:
#   11              : D#, G, A#, C#, F, G#
#   m11             : D#, F#, A#, C#, F, G#
#   M11             : D#, G, A#, D, F, G#
#   mM11            : D#, F#, A#, D, F, G#
#   +M11            : D#, G, B, D, F, G#
#   +11             : D#, G, B, C#, F, G#
#   ø11             : D#, F#, A, C#, F, G#
#   o11             : D#, F#, A, C, F, G#
# Thirteens Chords:
#   13              : D#, G, A#, C#, F, G#, C
#   m13             : D#, F#, A#, C#, F, G#, C
#   M13             : D#, G, A#, D, F, G#, C
#   mM13            : D#, F#, A#, D, F, G#, C
#   +M13            : D#, G, B, D, F, G#, C
#   +13             : D#, G, B, C#, F, G#, C
#   ø13             : D#, F#, A, C#, F, G#, C
#   Matches: b5
#
# Synthetic Chord 4: ['E', 'G#', 'C']
# Matching Chord: ['E', 'G#', 'C']
# Triads Chords:
#   M               : E, G#, B
#   m               : E, G, B
#   +               : E, G#, C
#   o               : E, G, A#
#   b5              : E, G#, A#
#   sus4            : E, A, B
# Sevenths Chords:
#   7               : E, G#, B, D
#   M7              : E, G#, B, D#
#   mM7             : E, G, B, D#
#   m7              : E, G, B, D
#   +M7             : E, G#, C, D#
#   +7              : E, G#, C, D
#   ø               : E, G, A#, D
#   o7              : E, G, A#, C#
#   7b5             : E, G#, A#, D
# Nines Chords:
#   M9              : E, G#, B, D#, F#
#   9               : E, G#, B, D, F#
#   7b9             : E, G#, B, D, F
#   m9              : E, G, B, D, F#
#   mM9             : E, G, B, D#, F#
#   +M9             : E, G#, C, D#, F#
#   +9              : E, G#, C, D, F#
#   ø9              : E, G, A#, D, F#
#   o9              : E, G, A#, C#, F#
#   ob9             : E, G, A#, C#, F
# Elevens Chords:
#   11              : E, G#, B, D, F#, A
#   m11             : E, G, B, D, F#, A
#   M11             : E, G#, B, D#, F#, A
#   mM11            : E, G, B, D#, F#, A
#   +M11            : E, G#, C, D#, F#, A
#   +11             : E, G#, C, D, F#, A
#   ø11             : E, G, A#, D, F#, A
#   o11             : E, G, A#, C#, F#, A
# Thirteens Chords:
#   13              : E, G#, B, D, F#, A, C#
#   m13             : E, G, B, D, F#, A, C#
#   M13             : E, G#, B, D#, F#, A, C#
#   mM13            : E, G, B, D#, F#, A, C#
#   +M13            : E, G#, C, D#, F#, A, C#
#   +13             : E, G#, C, D, F#, A, C#
#   ø13             : E, G, A#, D, F#, A, C#
#   Matches: +
#
# Synthetic Chord 5: ['G', 'A', 'C#']
# Matching Chord: ['G', 'A', 'C#']
# Triads Chords:
#   M               : G, B, D
#   m               : G, A#, D
#   +               : G, B, D#
#   o               : G, A#, C#
#   b5              : G, B, C#
#   sus4            : G, C, D
# Sevenths Chords:
#   7               : G, B, D, F
#   M7              : G, B, D, F#
#   mM7             : G, A#, D, F#
#   m7              : G, A#, D, F
#   +M7             : G, B, D#, F#
#   +7              : G, B, D#, F
#   ø               : G, A#, C#, F
#   o7              : G, A#, C#, E
#   7b5             : G, B, C#, F
# Nines Chords:
#   M9              : G, B, D, F#, A
#   9               : G, B, D, F, A
#   7b9             : G, B, D, F, G#
#   m9              : G, A#, D, F, A
#   mM9             : G, A#, D, F#, A
#   +M9             : G, B, D#, F#, A
#   +9              : G, B, D#, F, A
#   ø9              : G, A#, C#, F, A
#   o9              : G, A#, C#, E, A
#   ob9             : G, A#, C#, E, G#
# Elevens Chords:
#   11              : G, B, D, F, A, C
#   m11             : G, A#, D, F, A, C
#   M11             : G, B, D, F#, A, C
#   mM11            : G, A#, D, F#, A, C
#   +M11            : G, B, D#, F#, A, C
#   +11             : G, B, D#, F, A, C
#   ø11             : G, A#, C#, F, A, C
#   o11             : G, A#, C#, E, A, C
# Thirteens Chords:
#   13              : G, B, D, F, A, C, E
#   m13             : G, A#, D, F, A, C, E
#   M13             : G, B, D, F#, A, C, E
#   mM13            : G, A#, D, F#, A, C, E
#   +M13            : G, B, D#, F#, A, C, E
#   +13             : G, B, D#, F, A, C, E
#   ø13             : G, A#, C#, F, A, C, E
#   No matches found
#
# Synthetic Chord 6: ['G#', 'C', 'D#']
# Matching Chord: ['G#', 'C', 'D#']
# Triads Chords:
#   M               : G#, C, D#
#   m               : G#, B, D#
#   +               : G#, C, E
#   o               : G#, B, D
#   b5              : G#, C, D
#   sus4            : G#, C#, D#
# Sevenths Chords:
#   7               : G#, C, D#, F#
#   M7              : G#, C, D#, G
#   mM7             : G#, B, D#, G
#   m7              : G#, B, D#, F#
#   +M7             : G#, C, E, G
#   +7              : G#, C, E, F#
#   ø               : G#, B, D, F#
#   o7              : G#, B, D, F
#   7b5             : G#, C, D, F#
# Nines Chords:
#   M9              : G#, C, D#, G, A#
#   9               : G#, C, D#, F#, A#
#   7b9             : G#, C, D#, F#, A
#   m9              : G#, B, D#, F#, A#
#   mM9             : G#, B, D#, G, A#
#   +M9             : G#, C, E, G, A#
#   +9              : G#, C, E, F#, A#
#   ø9              : G#, B, D, F#, A#
#   o9              : G#, B, D, F, A#
#   ob9             : G#, B, D, F, A
# Elevens Chords:
#   11              : G#, C, D#, F#, A#, C#
#   m11             : G#, B, D#, F#, A#, C#
#   M11             : G#, C, D#, G, A#, C#
#   mM11            : G#, B, D#, G, A#, C#
#   +M11            : G#, C, E, G, A#, C#
#   +11             : G#, C, E, F#, A#, C#
#   ø11             : G#, B, D, F#, A#, C#
#   o11             : G#, B, D, F, A#, C#
# Thirteens Chords:
#   13              : G#, C, D#, F#, A#, C#, F
#   m13             : G#, B, D#, F#, A#, C#, F
#   M13             : G#, C, D#, G, A#, C#, F
#   mM13            : G#, B, D#, G, A#, C#, F
#   +M13            : G#, C, E, G, A#, C#, F
#   +13             : G#, C, E, F#, A#, C#, F
#   ø13             : G#, B, D, F#, A#, C#, F
#   Matches: M
#
# Synthetic Chord 7: ['A', 'C#', 'E']
# Matching Chord: ['A', 'C#', 'E']
# Triads Chords:
#   M               : A, C#, E
#   m               : A, C, E
#   +               : A, C#, F
#   o               : A, C, D#
#   b5              : A, C#, D#
#   sus4            : A, D, E
# Sevenths Chords:
#   7               : A, C#, E, G
#   M7              : A, C#, E, G#
#   mM7             : A, C, E, G#
#   m7              : A, C, E, G
#   +M7             : A, C#, F, G#
#   +7              : A, C#, F, G
#   ø               : A, C, D#, G
#   o7              : A, C, D#, F#
#   7b5             : A, C#, D#, G
# Nines Chords:
#   M9              : A, C#, E, G#, B
#   9               : A, C#, E, G, B
#   7b9             : A, C#, E, G, A#
#   m9              : A, C, E, G, B
#   mM9             : A, C, E, G#, B
#   +M9             : A, C#, F, G#, B
#   +9              : A, C#, F, G, B
#   ø9              : A, C, D#, G, B
#   o9              : A, C, D#, F#, B
#   ob9             : A, C, D#, F#, A#
# Elevens Chords:
#   11              : A, C#, E, G, B, D
#   m11             : A, C, E, G, B, D
#   M11             : A, C#, E, G#, B, D
#   mM11            : A, C, E, G#, B, D
#   +M11            : A, C#, F, G#, B, D
#   +11             : A, C#, F, G, B, D
#   ø11             : A, C, D#, G, B, D
#   o11             : A, C, D#, F#, B, D
# Thirteens Chords:
#   13              : A, C#, E, G, B, D, F#
#   m13             : A, C, E, G, B, D, F#
#   M13             : A, C#, E, G#, B, D, F#
#   mM13            : A, C, E, G#, B, D, F#
#   +M13            : A, C#, F, G#, B, D, F#
#   +13             : A, C#, F, G, B, D, F#
#   ø13             : A, C, D#, G, B, D, F#
#   Matches: M
#
# Synthetic Chord 8: ['C', 'D#', 'G']
# Matching Chord: ['C', 'D#', 'G']
# Triads Chords:
#   M               : C, E, G
#   m               : C, D#, G
#   +               : C, E, G#
#   o               : C, D#, F#
#   b5              : C, E, F#
#   sus4            : C, F, G
# Sevenths Chords:
#   7               : C, E, G, A#
#   M7              : C, E, G, B
#   mM7             : C, D#, G, B
#   m7              : C, D#, G, A#
#   +M7             : C, E, G#, B
#   +7              : C, E, G#, A#
#   ø               : C, D#, F#, A#
#   o7              : C, D#, F#, A
#   7b5             : C, E, F#, A#
# Nines Chords:
#   M9              : C, E, G, B, D
#   9               : C, E, G, A#, D
#   7b9             : C, E, G, A#, C#
#   m9              : C, D#, G, A#, D
#   mM9             : C, D#, G, B, D
#   +M9             : C, E, G#, B, D
#   +9              : C, E, G#, A#, D
#   ø9              : C, D#, F#, A#, D
#   o9              : C, D#, F#, A, D
#   ob9             : C, D#, F#, A, C#
# Elevens Chords:
#   11              : C, E, G, A#, D, F
#   m11             : C, D#, G, A#, D, F
#   M11             : C, E, G, B, D, F
#   mM11            : C, D#, G, B, D, F
#   +M11            : C, E, G#, B, D, F
#   +11             : C, E, G#, A#, D, F
#   ø11             : C, D#, F#, A#, D, F
#   o11             : C, D#, F#, A, D, F
# Thirteens Chords:
#   13              : C, E, G, A#, D, F, A
#   m13             : C, D#, G, A#, D, F, A
#   M13             : C, E, G, B, D, F, A
#   mM13            : C, D#, G, B, D, F, A
#   +M13            : C, E, G#, B, D, F, A
#   +13             : C, E, G#, A#, D, F, A
#   ø13             : C, D#, F#, A#, D, F, A
#   Matches: m
